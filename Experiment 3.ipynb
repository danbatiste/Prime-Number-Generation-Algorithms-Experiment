# %%
# Experiment 3.ipynb - third version of this file
# Author: Dan Batiste

# %%
# Imports and functions
import random as rand
from math import *
import time
import numpy as np

from algorithms import *

# %%
# Helper functions and classes

def create_csv(experiment_data, csv_path="experiment_data.csv", mode='write'):
    if mode in ['w', 'write']:
        with open(csv_path, 'w') as file:
            header = "interval_width,algorithm,replication_number,interval_start,interval_end,duration"
            header = header + '\n'
            file.write(header)
            for replication in experiment_data["Replications"]:
                line = ",".join([str(x).replace(',', ' ') for x in [
                    replication.treatment,
                    replication.algorithm_name,
                    replication.replication_number,
                    replication.interval[0],
                    replication.interval[1],
                    replication.duration,
                    #replication.primes_per_second,
                ]]) + '\n'
                file.write(line)

    if mode in ['append', 'a']:
        with open(csv_path, 'a') as file:
            for replication in experiment_data["Replications"]:
                line = ",".join([str(x).replace(',', ' ') for x in [
                    replication.treatment,
                    replication.algorithm_name,
                    replication.replication_number,
                    replication.interval[0],
                    replication.interval[1],
                    replication.duration,
                    #replication.primes_per_second,
                ]]) + '\n'
                file.write(line)
                
                
# Gets a random range given an interval
def random_interval(current_treatment, interval_width):
    # Get random range
    rand_choice_range = (current_treatment[0], current_treatment[1]) # [a, b]
    start = rand.randint(*rand_choice_range) # Inclusive: chooses 'a' for the [a,b] range to be used for the algorithm
    random_sample_range = start, start + interval_width
    return random_sample_range



class Replication():
    def __init__(self, treatment, algorithm_name, replication_number, interval, duration):
        self.treatment = treatment
        self.algorithm_name = algorithm_name
        self.replication_number = replication_number # Unused but I am leaving this in so code doesnt break
        self.interval = interval
        self.duration = duration
        #self.primes_per_second = len(interval)/duration
        
    def __repr__(self):
        return f"""
    treatment: {self.treatment}
    algorithm_name: {self.algorithm_name}
    replication_number: {self.replication_number}
    interval: {self.interval}
    duration: {self.duration}
"""
    
# Blueprint for Experiment object. Should really be named "Trial"
class Experiment():
    def __init__(self, algorithm_name, interval_width, interval):
        self.algorithm_name = algorithm_name
        self.interval_width = interval_width
        self.interval = interval
        
    def run(self):
        algorithm = eval(self.algorithm_name)
        start = time.time()
        results = algorithm(*self.interval)
        end = time.time()
        duration = end - start
        return Replication(self.interval_width, self.algorithm_name, -1, self.interval, duration)

# %%
## Main block

# Block to run the test
treatment_all = (1, 10**6)

# Settings
replications = 100 # Size of sample. This is our n. Each sample contains `replications` trials. Should be 100 in the actual experiment

# Algorithm names
algorithms = [
    "naive_algorithm",
    "sieve_of_eratosthenes",
    "sieve_of_sundaram",
]

# Initialize experiment data dictionary
experiment_data = {"Replications":[], "total_durations" : dict(zip(algorithms, [None]*len(algorithms)))}
experiments = []

# Create experiments
for interval_width in [10, 100, 1000, 10000]:
    for algorithm_name in algorithms:
        for replication in range(replications):
            interval = random_interval(treatment_all, interval_width)
            experiment = Experiment(algorithm_name, interval_width, interval)
            experiments.append(experiment)

print(f"Experiments created")
rand.shuffle(experiments) # Randomize order of experiments

# Run (randomized order) experiments 
print(len(experiments), "experiments")
start_experiments = time.time()
for i, experiment in enumerate(experiments):
    if i % 1 == 0:
        seconds = round(time.time() - start_experiments, 2)
        print(f"{seconds}: running experiment #{i}: {experiment.algorithm_name} {experiment.interval}")
    replication = experiment.run()
    experiment_data["Replications"].append(replication)

print("done")

# Write to .csv
create_csv(experiment_data, csv_path=f"experiment_data_3_final 6.3.0259.csv")
# Out:
# Experiments created
# 1200 experiments
# 0.0: running experiment #0: sieve_of_eratosthenes (58992, 68992)
# 0.01: running experiment #1: naive_algorithm (840951, 850951)
# 0.07: running experiment #2: sieve_of_eratosthenes (494891, 495891)
# 0.14: running experiment #3: sieve_of_eratosthenes (254492, 255492)
# 0.17: running experiment #4: sieve_of_sundaram (420819, 421819)
# 0.35: running experiment #5: naive_algorithm (316499, 316599)
# 0.35: running experiment #6: sieve_of_eratosthenes (648334, 648344)
# 0.43: running experiment #7: sieve_of_sundaram (853516, 854516)
# 0.81: running experiment #8: sieve_of_eratosthenes (157134, 157144)
# 0.83: running experiment #9: sieve_of_sundaram (752912, 753912)
# 1.17: running experiment #10: naive_algorithm (793382, 793392)
# 1.17: running experiment #11: sieve_of_sundaram (540298, 540398)
# 1.4: running experiment #12: naive_algorithm (232120, 232220)
# 1.4: running experiment #13: naive_algorithm (349227, 349327)
# 1.4: running experiment #14: sieve_of_sundaram (533908, 534908)
# 1.63: running experiment #15: sieve_of_sundaram (104774, 114774)
# 1.68: running experiment #16: naive_algorithm (815397, 815497)
# 1.68: running experiment #17: naive_algorithm (620483, 630483)
# 1.73: running experiment #18: sieve_of_eratosthenes (443435, 453435)
# 1.78: running experiment #19: sieve_of_eratosthenes (39171, 39181)
# 1.79: running experiment #20: sieve_of_eratosthenes (961217, 971217)
# 1.92: running experiment #21: naive_algorithm (283427, 283527)
# 1.92: running experiment #22: naive_algorithm (841356, 851356)
# 1.97: running experiment #23: sieve_of_sundaram (53454, 53554)
# 1.99: running experiment #24: sieve_of_eratosthenes (613335, 623335)
# 2.07: running experiment #25: naive_algorithm (668794, 668894)
# 2.07: running experiment #26: naive_algorithm (603678, 603778)
# 2.07: running experiment #27: naive_algorithm (459768, 469768)
# 2.11: running experiment #28: sieve_of_eratosthenes (773610, 783610)
# 2.22: running experiment #29: sieve_of_sundaram (843913, 853913)
# 2.59: running experiment #30: sieve_of_sundaram (870827, 880827)
# 2.98: running experiment #31: sieve_of_eratosthenes (14097, 15097)
# 2.98: running experiment #32: sieve_of_sundaram (225034, 226034)
# 3.07: running experiment #33: naive_algorithm (743990, 744090)
# 3.07: running experiment #34: sieve_of_eratosthenes (469790, 479790)
# 3.13: running experiment #35: sieve_of_eratosthenes (550024, 551024)
# 3.2: running experiment #36: sieve_of_eratosthenes (731910, 732010)
# 3.3: running experiment #37: sieve_of_sundaram (317789, 317889)
# 3.42: running experiment #38: sieve_of_eratosthenes (433003, 433013)
# 3.49: running experiment #39: naive_algorithm (887653, 887663)
# 3.49: running experiment #40: sieve_of_eratosthenes (649729, 649829)
# 3.59: running experiment #41: naive_algorithm (618651, 628651)
# 3.64: running experiment #42: sieve_of_eratosthenes (706064, 706164)
# 3.74: running experiment #43: naive_algorithm (5126, 5136)
# 3.74: running experiment #44: naive_algorithm (829775, 830775)
# 3.74: running experiment #45: sieve_of_sundaram (132513, 133513)
# 3.8: running experiment #46: sieve_of_sundaram (911415, 911425)
# 4.21: running experiment #47: sieve_of_sundaram (31876, 41876)
# 4.23: running experiment #48: sieve_of_eratosthenes (917461, 917561)
# 4.35: running experiment #49: sieve_of_eratosthenes (309155, 310155)
# 4.38: running experiment #50: sieve_of_sundaram (42150, 52150)
# 4.4: running experiment #51: naive_algorithm (151187, 161187)
# 4.43: running experiment #52: sieve_of_eratosthenes (246409, 256409)
# 4.46: running experiment #53: naive_algorithm (560469, 560479)
# 4.46: running experiment #54: sieve_of_sundaram (438608, 448608)
# 4.66: running experiment #55: sieve_of_sundaram (28229, 28329)
# 4.67: running experiment #56: sieve_of_eratosthenes (215378, 216378)
# 4.69: running experiment #57: sieve_of_eratosthenes (751765, 761765)
# 4.79: running experiment #58: sieve_of_sundaram (554159, 554169)
# 5.03: running experiment #59: sieve_of_eratosthenes (710620, 720620)
# 5.12: running experiment #60: naive_algorithm (134549, 144549)
# 5.15: running experiment #61: naive_algorithm (176263, 177263)
# 5.15: running experiment #62: sieve_of_eratosthenes (16182, 16282)
# 5.15: running experiment #63: sieve_of_eratosthenes (667320, 667420)
# 5.24: running experiment #64: naive_algorithm (215465, 215565)
# 5.24: running experiment #65: sieve_of_eratosthenes (665815, 675815)
# 5.33: running experiment #66: sieve_of_eratosthenes (505157, 505167)
# 5.39: running experiment #67: naive_algorithm (125385, 135385)
# 5.42: running experiment #68: sieve_of_eratosthenes (866264, 866364)
# 5.53: running experiment #69: sieve_of_eratosthenes (531618, 531628)
# 5.6: running experiment #70: sieve_of_eratosthenes (105647, 106647)
# 5.62: running experiment #71: naive_algorithm (148352, 148452)
# 5.62: running experiment #72: sieve_of_sundaram (599154, 599164)
# 5.88: running experiment #73: naive_algorithm (970637, 980637)
# 5.94: running experiment #74: sieve_of_sundaram (708899, 708999)
# 6.26: running experiment #75: naive_algorithm (843222, 843232)
# 6.26: running experiment #76: sieve_of_eratosthenes (551271, 551371)
# 6.34: running experiment #77: naive_algorithm (537797, 537807)
# 6.34: running experiment #78: naive_algorithm (5889, 15889)
# 6.35: running experiment #79: naive_algorithm (238187, 248187)
# 6.38: running experiment #80: sieve_of_eratosthenes (103493, 103503)
# 6.39: running experiment #81: sieve_of_eratosthenes (724830, 725830)
# 6.49: running experiment #82: sieve_of_sundaram (53609, 53709)
# 6.5: running experiment #83: naive_algorithm (141746, 141846)
# 6.5: running experiment #84: sieve_of_sundaram (428552, 428562)
# 6.69: running experiment #85: sieve_of_sundaram (548047, 549047)
# 6.92: running experiment #86: naive_algorithm (706975, 707975)
# 6.93: running experiment #87: sieve_of_eratosthenes (184490, 194490)
# 6.95: running experiment #88: naive_algorithm (469931, 470931)
# 6.95: running experiment #89: sieve_of_sundaram (983869, 984869)
# 7.39: running experiment #90: naive_algorithm (708141, 718141)
# 7.45: running experiment #91: sieve_of_sundaram (557453, 558453)
# 7.68: running experiment #92: sieve_of_eratosthenes (333635, 333735)
# 7.72: running experiment #93: sieve_of_sundaram (163522, 164522)
# 7.79: running experiment #94: sieve_of_eratosthenes (761484, 771484)
# 7.88: running experiment #95: sieve_of_eratosthenes (926287, 926297)
# 8.01: running experiment #96: naive_algorithm (437662, 437762)
# 8.01: running experiment #97: naive_algorithm (185427, 186427)
# 8.01: running experiment #98: naive_algorithm (492058, 492068)
# 8.01: running experiment #99: sieve_of_sundaram (677129, 677229)
# 8.31: running experiment #100: sieve_of_sundaram (503293, 504293)
# 8.52: running experiment #101: naive_algorithm (983507, 983517)
# 8.52: running experiment #102: sieve_of_eratosthenes (603667, 613667)
# 8.61: running experiment #103: sieve_of_sundaram (860771, 870771)
# 8.99: running experiment #104: naive_algorithm (614907, 615007)
# 8.99: running experiment #105: naive_algorithm (702826, 712826)
# 9.04: running experiment #106: sieve_of_eratosthenes (681739, 681749)
# 9.13: running experiment #107: sieve_of_sundaram (603888, 603898)
# 9.39: running experiment #108: naive_algorithm (945495, 955495)
# 9.44: running experiment #109: sieve_of_sundaram (708345, 708445)
# 9.76: running experiment #110: naive_algorithm (126840, 127840)
# 9.76: running experiment #111: sieve_of_sundaram (711832, 711842)
# 10.07: running experiment #112: sieve_of_eratosthenes (993965, 994065)
# 10.2: running experiment #113: sieve_of_sundaram (180953, 181053)
# 10.27: running experiment #114: sieve_of_eratosthenes (588754, 589754)
# 10.35: running experiment #115: naive_algorithm (497267, 507267)
# 10.4: running experiment #116: sieve_of_sundaram (376721, 376821)
# 10.55: running experiment #117: naive_algorithm (547803, 547813)
# 10.55: running experiment #118: sieve_of_eratosthenes (439191, 440191)
# 10.61: running experiment #119: sieve_of_eratosthenes (266198, 266208)
# 10.64: running experiment #120: sieve_of_eratosthenes (623803, 633803)
# 10.72: running experiment #121: naive_algorithm (61605, 61615)
# 10.72: running experiment #122: naive_algorithm (590236, 590246)
# 10.72: running experiment #123: sieve_of_eratosthenes (760887, 770887)
# 10.82: running experiment #124: sieve_of_sundaram (894255, 895255)
# 11.23: running experiment #125: sieve_of_sundaram (300147, 300157)
# 11.37: running experiment #126: sieve_of_sundaram (165637, 165647)
# 11.43: running experiment #127: sieve_of_eratosthenes (827560, 827570)
# 11.55: running experiment #128: sieve_of_sundaram (570992, 580992)
# 11.8: running experiment #129: naive_algorithm (937037, 938037)
# 11.8: running experiment #130: sieve_of_eratosthenes (793057, 794057)
# 11.91: running experiment #131: sieve_of_eratosthenes (799461, 809461)
# 12.01: running experiment #132: sieve_of_sundaram (637803, 638803)
# 12.29: running experiment #133: sieve_of_sundaram (183274, 193274)
# 12.37: running experiment #134: naive_algorithm (378045, 378055)
# 12.37: running experiment #135: sieve_of_sundaram (253586, 253596)
# 12.47: running experiment #136: sieve_of_sundaram (372791, 382791)
# 12.63: running experiment #137: naive_algorithm (510393, 520393)
# 12.67: running experiment #138: sieve_of_sundaram (62899, 62909)
# 12.69: running experiment #139: naive_algorithm (535949, 536049)
# 12.7: running experiment #140: sieve_of_sundaram (785071, 786071)
# 13.04: running experiment #141: naive_algorithm (827895, 828895)
# 13.05: running experiment #142: naive_algorithm (835502, 845502)
# 13.1: running experiment #143: sieve_of_sundaram (136283, 136293)
# 13.16: running experiment #144: naive_algorithm (846305, 847305)
# 13.16: running experiment #145: sieve_of_sundaram (250465, 251465)
# 13.26: running experiment #146: sieve_of_sundaram (417005, 418005)
# 13.44: running experiment #147: sieve_of_sundaram (192345, 192355)
# 13.51: running experiment #148: naive_algorithm (622410, 632410)
# 13.56: running experiment #149: sieve_of_sundaram (634773, 634873)
# 13.84: running experiment #150: sieve_of_eratosthenes (554727, 564727)
# 13.91: running experiment #151: sieve_of_sundaram (310819, 310919)
# 14.04: running experiment #152: naive_algorithm (471592, 471692)
# 14.04: running experiment #153: sieve_of_sundaram (429407, 429417)
# 14.22: running experiment #154: naive_algorithm (752423, 752433)
# 14.22: running experiment #155: sieve_of_sundaram (641022, 651022)
# 14.51: running experiment #156: sieve_of_eratosthenes (687530, 687630)
# 14.6: running experiment #157: naive_algorithm (424099, 425099)
# 14.6: running experiment #158: sieve_of_sundaram (176520, 186520)
# 14.68: running experiment #159: naive_algorithm (261346, 262346)
# 14.68: running experiment #160: naive_algorithm (444298, 444398)
# 14.68: running experiment #161: sieve_of_sundaram (156433, 157433)
# 14.74: running experiment #162: sieve_of_sundaram (432075, 432175)
# 14.92: running experiment #163: naive_algorithm (681659, 682659)
# 14.92: running experiment #164: sieve_of_eratosthenes (741238, 741338)
# 15.02: running experiment #165: sieve_of_sundaram (699672, 699772)
# 15.33: running experiment #166: naive_algorithm (245124, 255124)
# 15.37: running experiment #167: sieve_of_sundaram (510579, 520579)
# 15.59: running experiment #168: naive_algorithm (426400, 426410)
# 15.59: running experiment #169: sieve_of_sundaram (153830, 154830)
# 15.65: running experiment #170: naive_algorithm (811308, 811318)
# 15.65: running experiment #171: sieve_of_eratosthenes (154574, 155574)
# 15.67: running experiment #172: sieve_of_sundaram (918692, 918702)
# 16.07: running experiment #173: naive_algorithm (804053, 805053)
# 16.08: running experiment #174: sieve_of_sundaram (166919, 176919)
# 16.15: running experiment #175: sieve_of_eratosthenes (441306, 451306)
# 16.21: running experiment #176: sieve_of_eratosthenes (738848, 748848)
# 16.3: running experiment #177: naive_algorithm (873183, 873283)
# 16.3: running experiment #178: sieve_of_sundaram (709799, 719799)
# 16.62: running experiment #179: naive_algorithm (217383, 227383)
# 16.65: running experiment #180: sieve_of_eratosthenes (879545, 889545)
# 16.77: running experiment #181: naive_algorithm (730701, 730711)
# 16.77: running experiment #182: sieve_of_eratosthenes (57054, 67054)
# 16.77: running experiment #183: naive_algorithm (769579, 779579)
# 16.83: running experiment #184: sieve_of_sundaram (823542, 833542)
# 17.2: running experiment #185: sieve_of_sundaram (64812, 65812)
# 17.22: running experiment #186: sieve_of_eratosthenes (139043, 140043)
# 17.24: running experiment #187: sieve_of_sundaram (838151, 839151)
# 17.61: running experiment #188: sieve_of_eratosthenes (142383, 152383)
# 17.63: running experiment #189: sieve_of_sundaram (507045, 508045)
# 17.84: running experiment #190: sieve_of_eratosthenes (496322, 496332)
# 17.91: running experiment #191: sieve_of_eratosthenes (325263, 325273)
# 17.95: running experiment #192: naive_algorithm (204195, 205195)
# 17.95: running experiment #193: naive_algorithm (406196, 406206)
# 17.95: running experiment #194: sieve_of_eratosthenes (717683, 727683)
# 18.05: running experiment #195: sieve_of_eratosthenes (324009, 324019)
# 18.09: running experiment #196: sieve_of_eratosthenes (417587, 427587)
# 18.14: running experiment #197: sieve_of_sundaram (710621, 710631)
# 18.45: running experiment #198: naive_algorithm (943395, 943405)
# 18.45: running experiment #199: sieve_of_sundaram (859728, 860728)
# 18.84: running experiment #200: naive_algorithm (322366, 332366)
# 18.88: running experiment #201: sieve_of_sundaram (683348, 683358)
# 19.18: running experiment #202: sieve_of_sundaram (594853, 604853)
# 19.44: running experiment #203: naive_algorithm (396122, 397122)
# 19.44: running experiment #204: naive_algorithm (380054, 380154)
# 19.44: running experiment #205: naive_algorithm (159933, 159943)
# 19.44: running experiment #206: sieve_of_eratosthenes (662796, 672796)
# 19.53: running experiment #207: sieve_of_eratosthenes (935440, 945440)
# 19.66: running experiment #208: naive_algorithm (138915, 148915)
# 19.68: running experiment #209: sieve_of_eratosthenes (439333, 439433)
# 19.74: running experiment #210: naive_algorithm (323908, 333908)
# 19.78: running experiment #211: sieve_of_sundaram (488786, 489786)
# 19.98: running experiment #212: sieve_of_sundaram (937679, 947679)
# 20.42: running experiment #213: sieve_of_sundaram (348902, 348912)
# 20.56: running experiment #214: sieve_of_sundaram (144314, 144414)
# 20.61: running experiment #215: naive_algorithm (829269, 829279)
# 20.61: running experiment #216: sieve_of_sundaram (729758, 739758)
# 20.94: running experiment #217: naive_algorithm (765374, 765384)
# 20.94: running experiment #218: sieve_of_sundaram (737791, 738791)
# 21.26: running experiment #219: sieve_of_sundaram (667609, 667709)
# 21.55: running experiment #220: naive_algorithm (19559, 29559)
# 21.56: running experiment #221: naive_algorithm (999479, 999489)
# 21.56: running experiment #222: sieve_of_eratosthenes (212661, 222661)
# 21.59: running experiment #223: sieve_of_sundaram (476278, 486278)
# 21.79: running experiment #224: sieve_of_sundaram (184429, 184439)
# 21.86: running experiment #225: sieve_of_sundaram (730640, 730740)
# 22.18: running experiment #226: naive_algorithm (626599, 626699)
# 22.19: running experiment #227: sieve_of_sundaram (703511, 703521)
# 22.49: running experiment #228: sieve_of_sundaram (34023, 44023)
# 22.51: running experiment #229: naive_algorithm (477188, 478188)
# 22.51: running experiment #230: sieve_of_sundaram (622878, 622888)
# 22.78: running experiment #231: sieve_of_eratosthenes (185639, 185739)
# 22.8: running experiment #232: sieve_of_sundaram (505316, 505326)
# 23.02: running experiment #233: sieve_of_sundaram (266256, 266266)
# 23.13: running experiment #234: sieve_of_eratosthenes (268937, 269937)
# 23.16: running experiment #235: naive_algorithm (768256, 768356)
# 23.16: running experiment #236: naive_algorithm (936279, 936289)
# 23.16: running experiment #237: sieve_of_eratosthenes (397073, 398073)
# 23.21: running experiment #238: sieve_of_sundaram (185212, 185312)
# 23.29: running experiment #239: naive_algorithm (293230, 294230)
# 23.29: running experiment #240: sieve_of_eratosthenes (574983, 575983)
# 23.37: running experiment #241: sieve_of_sundaram (516441, 526441)
# 23.59: running experiment #242: naive_algorithm (111129, 121129)
# 23.61: running experiment #243: naive_algorithm (436271, 437271)
# 23.61: running experiment #244: sieve_of_eratosthenes (357649, 357659)
# 23.66: running experiment #245: naive_algorithm (104788, 105788)
# 23.66: running experiment #246: naive_algorithm (932047, 932147)
# 23.66: running experiment #247: sieve_of_sundaram (128941, 138941)
# 23.71: running experiment #248: naive_algorithm (691130, 691140)
# 23.71: running experiment #249: sieve_of_eratosthenes (253530, 263530)
# 23.75: running experiment #250: sieve_of_eratosthenes (900508, 910508)
# 23.86: running experiment #251: naive_algorithm (699823, 699833)
# 23.86: running experiment #252: naive_algorithm (42943, 52943)
# 23.88: running experiment #253: sieve_of_eratosthenes (119025, 129025)
# 23.9: running experiment #254: sieve_of_eratosthenes (130224, 130324)
# 23.91: running experiment #255: naive_algorithm (543195, 553195)
# 23.96: running experiment #256: sieve_of_eratosthenes (867541, 867641)
# 24.07: running experiment #257: sieve_of_eratosthenes (842927, 842937)
# 24.18: running experiment #258: sieve_of_eratosthenes (430100, 431100)
# 24.23: running experiment #259: sieve_of_sundaram (439384, 439484)
# 24.42: running experiment #260: sieve_of_eratosthenes (962730, 972730)
# 24.55: running experiment #261: sieve_of_eratosthenes (792326, 802326)
# 24.65: running experiment #262: sieve_of_eratosthenes (24026, 34026)
# 24.66: running experiment #263: sieve_of_sundaram (723959, 733959)
# 24.98: running experiment #264: sieve_of_sundaram (799180, 799190)
# 25.34: running experiment #265: sieve_of_eratosthenes (7346, 7446)
# 25.34: running experiment #266: sieve_of_sundaram (495448, 496448)
# 25.56: running experiment #267: naive_algorithm (873638, 873648)
# 25.56: running experiment #268: naive_algorithm (896667, 906667)
# 25.61: running experiment #269: naive_algorithm (60739, 60749)
# 25.61: running experiment #270: sieve_of_sundaram (256162, 257162)
# 25.71: running experiment #271: sieve_of_sundaram (995937, 1005937)
# 26.17: running experiment #272: sieve_of_sundaram (131421, 141421)
# 26.22: running experiment #273: naive_algorithm (947640, 948640)
# 26.23: running experiment #274: sieve_of_eratosthenes (805159, 805259)
# 26.33: running experiment #275: sieve_of_eratosthenes (353902, 354002)
# 26.38: running experiment #276: sieve_of_eratosthenes (642024, 643024)
# 26.46: running experiment #277: naive_algorithm (935406, 935416)
# 26.46: running experiment #278: sieve_of_sundaram (596146, 596246)
# 26.72: running experiment #279: naive_algorithm (896696, 897696)
# 26.72: running experiment #280: naive_algorithm (366441, 367441)
# 26.73: running experiment #281: sieve_of_eratosthenes (380624, 390624)
# 26.77: running experiment #282: sieve_of_sundaram (166236, 166246)
# 26.84: running experiment #283: sieve_of_eratosthenes (297010, 307010)
# 26.87: running experiment #284: sieve_of_eratosthenes (950452, 950552)
# 27.0: running experiment #285: naive_algorithm (923728, 933728)
# 27.06: running experiment #286: sieve_of_eratosthenes (923000, 924000)
# 27.18: running experiment #287: sieve_of_sundaram (392769, 393769)
# 27.34: running experiment #288: sieve_of_eratosthenes (690533, 690633)
# 27.43: running experiment #289: naive_algorithm (253144, 253154)
# 27.43: running experiment #290: sieve_of_sundaram (261015, 261115)
# 27.54: running experiment #291: naive_algorithm (192079, 193079)
# 27.54: running experiment #292: sieve_of_eratosthenes (922582, 923582)
# 27.66: running experiment #293: sieve_of_sundaram (154706, 155706)
# 27.72: running experiment #294: naive_algorithm (552564, 552574)
# 27.72: running experiment #295: naive_algorithm (683323, 683333)
# 27.72: running experiment #296: sieve_of_eratosthenes (260217, 261217)
# 27.75: running experiment #297: naive_algorithm (782954, 782964)
# 27.75: running experiment #298: naive_algorithm (268982, 269982)
# 27.76: running experiment #299: sieve_of_sundaram (167855, 167955)
# 27.82: running experiment #300: sieve_of_sundaram (455235, 455245)
# 28.01: running experiment #301: sieve_of_eratosthenes (920442, 930442)
# 28.13: running experiment #302: sieve_of_sundaram (214049, 214059)
# 28.21: running experiment #303: sieve_of_eratosthenes (639312, 649312)
# 28.3: running experiment #304: sieve_of_eratosthenes (121285, 121385)
# 28.31: running experiment #305: sieve_of_sundaram (645043, 645143)
# 28.59: running experiment #306: sieve_of_sundaram (529874, 539874)
# 28.82: running experiment #307: sieve_of_sundaram (807213, 807223)
# 29.18: running experiment #308: sieve_of_sundaram (402722, 412722)
# 29.35: running experiment #309: naive_algorithm (955727, 955827)
# 29.35: running experiment #310: sieve_of_eratosthenes (258011, 268011)
# 29.38: running experiment #311: sieve_of_eratosthenes (716916, 726916)
# 29.48: running experiment #312: naive_algorithm (508248, 508348)
# 29.48: running experiment #313: sieve_of_sundaram (472090, 472190)
# 29.67: running experiment #314: naive_algorithm (79185, 80185)
# 29.68: running experiment #315: naive_algorithm (310094, 311094)
# 29.68: running experiment #316: naive_algorithm (466581, 466681)
# 29.68: running experiment #317: sieve_of_sundaram (47722, 47822)
# 29.7: running experiment #318: sieve_of_eratosthenes (361508, 361518)
# 29.74: running experiment #319: naive_algorithm (474367, 484367)
# 29.79: running experiment #320: sieve_of_eratosthenes (889318, 890318)
# 29.91: running experiment #321: sieve_of_sundaram (606262, 607262)
# 30.18: running experiment #322: naive_algorithm (134916, 144916)
# 30.21: running experiment #323: naive_algorithm (100167, 110167)
# 30.23: running experiment #324: sieve_of_sundaram (608669, 618669)
# 30.5: running experiment #325: naive_algorithm (127098, 127198)
# 30.5: running experiment #326: sieve_of_sundaram (451838, 451938)
# 30.7: running experiment #327: naive_algorithm (560980, 561980)
# 30.7: running experiment #328: sieve_of_eratosthenes (658761, 668761)
# 30.78: running experiment #329: sieve_of_sundaram (896949, 906949)
# 31.19: running experiment #330: sieve_of_sundaram (316761, 317761)
# 31.32: running experiment #331: naive_algorithm (620419, 621419)
# 31.33: running experiment #332: sieve_of_sundaram (54036, 55036)
# 31.35: running experiment #333: naive_algorithm (200766, 200776)
# 31.35: running experiment #334: naive_algorithm (749024, 750024)
# 31.35: running experiment #335: sieve_of_sundaram (104666, 104766)
# 31.39: running experiment #336: sieve_of_eratosthenes (471360, 471370)
# 31.45: running experiment #337: naive_algorithm (702158, 703158)
# 31.46: running experiment #338: sieve_of_eratosthenes (767518, 767618)
# 31.56: running experiment #339: sieve_of_eratosthenes (632084, 632184)
# 31.64: running experiment #340: sieve_of_eratosthenes (180981, 180991)
# 31.66: running experiment #341: sieve_of_eratosthenes (943264, 944264)
# 31.78: running experiment #342: sieve_of_eratosthenes (259309, 259409)
# 31.81: running experiment #343: sieve_of_eratosthenes (958805, 958815)
# 31.94: running experiment #344: sieve_of_eratosthenes (364267, 364277)
# 31.98: running experiment #345: sieve_of_eratosthenes (960725, 960825)
# 32.11: running experiment #346: sieve_of_sundaram (158318, 158328)
# 32.17: running experiment #347: sieve_of_sundaram (363951, 364051)
# 32.33: running experiment #348: sieve_of_eratosthenes (802584, 803584)
# 32.44: running experiment #349: sieve_of_eratosthenes (382568, 383568)
# 32.49: running experiment #350: sieve_of_sundaram (111621, 111721)
# 32.53: running experiment #351: naive_algorithm (640132, 640232)
# 32.53: running experiment #352: sieve_of_eratosthenes (427377, 437377)
# 32.59: running experiment #353: sieve_of_eratosthenes (348063, 349063)
# 32.63: running experiment #354: naive_algorithm (695626, 696626)
# 32.64: running experiment #355: sieve_of_eratosthenes (855511, 855611)
# 32.75: running experiment #356: sieve_of_eratosthenes (357326, 367326)
# 32.79: running experiment #357: naive_algorithm (954355, 954365)
# 32.79: running experiment #358: naive_algorithm (71834, 71844)
# 32.79: running experiment #359: sieve_of_sundaram (920010, 921010)
# 33.23: running experiment #360: sieve_of_sundaram (875497, 885497)
# 33.63: running experiment #361: naive_algorithm (264535, 264635)
# 33.63: running experiment #362: sieve_of_eratosthenes (826379, 826479)
# 33.74: running experiment #363: naive_algorithm (643369, 643469)
# 33.74: running experiment #364: naive_algorithm (916484, 926484)
# 33.79: running experiment #365: sieve_of_eratosthenes (31342, 32342)
# 33.8: running experiment #366: sieve_of_eratosthenes (780139, 781139)
# 33.9: running experiment #367: sieve_of_eratosthenes (829628, 830628)
# 34.0: running experiment #368: sieve_of_eratosthenes (921441, 921451)
# 34.12: running experiment #369: sieve_of_sundaram (529616, 539616)
# 34.36: running experiment #370: sieve_of_sundaram (374498, 375498)
# 34.52: running experiment #371: sieve_of_sundaram (80082, 80182)
# 34.55: running experiment #372: naive_algorithm (232684, 232784)
# 34.55: running experiment #373: sieve_of_sundaram (354106, 354206)
# 34.7: running experiment #374: naive_algorithm (314598, 314608)
# 34.7: running experiment #375: sieve_of_sundaram (932726, 933726)
# 35.13: running experiment #376: sieve_of_eratosthenes (189263, 190263)
# 35.16: running experiment #377: naive_algorithm (842042, 842142)
# 35.16: running experiment #378: naive_algorithm (139402, 149402)
# 35.18: running experiment #379: sieve_of_eratosthenes (873481, 874481)
# 35.3: running experiment #380: naive_algorithm (186968, 187968)
# 35.3: running experiment #381: sieve_of_eratosthenes (132051, 133051)
# 35.32: running experiment #382: sieve_of_eratosthenes (850116, 850216)
# 35.43: running experiment #383: sieve_of_eratosthenes (972148, 972248)
# 35.56: running experiment #384: sieve_of_sundaram (630559, 631559)
# 35.84: running experiment #385: naive_algorithm (787143, 788143)
# 35.85: running experiment #386: sieve_of_sundaram (925400, 925500)
# 36.27: running experiment #387: sieve_of_sundaram (437602, 447602)
# 36.46: running experiment #388: sieve_of_eratosthenes (838549, 838649)
# 36.57: running experiment #389: sieve_of_eratosthenes (43337, 44337)
# 36.58: running experiment #390: naive_algorithm (825649, 825749)
# 36.58: running experiment #391: naive_algorithm (60102, 61102)
# 36.58: running experiment #392: naive_algorithm (224191, 224291)
# 36.58: running experiment #393: naive_algorithm (849788, 850788)
# 36.58: running experiment #394: naive_algorithm (907993, 908993)
# 36.59: running experiment #395: sieve_of_eratosthenes (952108, 953108)
# 36.71: running experiment #396: sieve_of_sundaram (337011, 347011)
# 36.85: running experiment #397: naive_algorithm (557720, 558720)
# 36.86: running experiment #398: sieve_of_sundaram (327868, 337868)
# 37.0: running experiment #399: naive_algorithm (812235, 822235)
# 37.05: running experiment #400: sieve_of_eratosthenes (204397, 204407)
# 37.08: running experiment #401: naive_algorithm (964471, 964481)
# 37.08: running experiment #402: sieve_of_sundaram (392773, 392873)
# 37.24: running experiment #403: sieve_of_eratosthenes (127830, 128830)
# 37.26: running experiment #404: sieve_of_sundaram (191040, 192040)
# 37.33: running experiment #405: sieve_of_sundaram (586995, 587995)
# 37.6: running experiment #406: naive_algorithm (94472, 104472)
# 37.62: running experiment #407: sieve_of_eratosthenes (731944, 741944)
# 37.72: running experiment #408: sieve_of_sundaram (540602, 540612)
# 37.95: running experiment #409: naive_algorithm (572796, 572896)
# 37.95: running experiment #410: naive_algorithm (437162, 437172)
# 37.95: running experiment #411: sieve_of_eratosthenes (745387, 745487)
# 38.04: running experiment #412: sieve_of_sundaram (689529, 690529)
# 38.35: running experiment #413: sieve_of_eratosthenes (205835, 205845)
# 38.37: running experiment #414: naive_algorithm (712420, 712430)
# 38.37: running experiment #415: sieve_of_sundaram (863978, 863988)
# 38.78: running experiment #416: naive_algorithm (975417, 975517)
# 38.78: running experiment #417: sieve_of_sundaram (931466, 931476)
# 39.2: running experiment #418: sieve_of_eratosthenes (948128, 958128)
# 39.33: running experiment #419: sieve_of_eratosthenes (841765, 841865)
# 39.44: running experiment #420: sieve_of_eratosthenes (151984, 161984)
# 39.46: running experiment #421: sieve_of_sundaram (198509, 199509)
# 39.54: running experiment #422: naive_algorithm (837853, 838853)
# 39.54: running experiment #423: naive_algorithm (371548, 371558)
# 39.54: running experiment #424: sieve_of_sundaram (96131, 96141)
# 39.58: running experiment #425: sieve_of_eratosthenes (56345, 56445)
# 39.59: running experiment #426: sieve_of_eratosthenes (356683, 356783)
# 39.63: running experiment #427: naive_algorithm (189953, 189963)
# 39.63: running experiment #428: sieve_of_sundaram (780826, 790826)
# 39.98: running experiment #429: sieve_of_eratosthenes (595826, 595926)
# 40.05: running experiment #430: naive_algorithm (857202, 867202)
# 40.11: running experiment #431: sieve_of_sundaram (371810, 371820)
# 40.26: running experiment #432: sieve_of_sundaram (848169, 849169)
# 40.64: running experiment #433: sieve_of_eratosthenes (252761, 252771)
# 40.67: running experiment #434: sieve_of_eratosthenes (920276, 921276)
# 40.79: running experiment #435: sieve_of_eratosthenes (904982, 914982)
# 40.91: running experiment #436: naive_algorithm (802774, 812774)
# 40.97: running experiment #437: naive_algorithm (918479, 918579)
# 40.97: running experiment #438: sieve_of_eratosthenes (259330, 259430)
# 41.0: running experiment #439: naive_algorithm (82136, 82236)
# 41.0: running experiment #440: naive_algorithm (574741, 584741)
# 41.05: running experiment #441: naive_algorithm (358771, 359771)
# 41.05: running experiment #442: sieve_of_sundaram (272366, 272466)
# 41.16: running experiment #443: naive_algorithm (181960, 181970)
# 41.16: running experiment #444: sieve_of_eratosthenes (617831, 617931)
# 41.25: running experiment #445: sieve_of_sundaram (297735, 297835)
# 41.37: running experiment #446: naive_algorithm (805487, 815487)
# 41.42: running experiment #447: sieve_of_sundaram (752841, 752941)
# 41.75: running experiment #448: naive_algorithm (954364, 954374)
# 41.75: running experiment #449: sieve_of_sundaram (156104, 156204)
# 41.81: running experiment #450: naive_algorithm (331618, 331718)
# 41.81: running experiment #451: sieve_of_eratosthenes (37327, 38327)
# 41.81: running experiment #452: naive_algorithm (3393, 4393)
# 41.81: running experiment #453: sieve_of_sundaram (25138, 25238)
# 41.82: running experiment #454: naive_algorithm (324098, 324108)
# 41.82: running experiment #455: naive_algorithm (590899, 590909)
# 41.82: running experiment #456: naive_algorithm (68534, 69534)
# 41.82: running experiment #457: sieve_of_eratosthenes (412480, 422480)
# 41.87: running experiment #458: sieve_of_eratosthenes (181569, 191569)
# 41.9: running experiment #459: naive_algorithm (565054, 565154)
# 41.9: running experiment #460: sieve_of_eratosthenes (245789, 245799)
# 41.93: running experiment #461: naive_algorithm (406436, 406446)
# 41.93: running experiment #462: sieve_of_eratosthenes (397680, 397690)
# 41.98: running experiment #463: sieve_of_eratosthenes (151346, 151356)
# 41.99: running experiment #464: sieve_of_eratosthenes (668967, 678967)
# 42.08: running experiment #465: naive_algorithm (807270, 817270)
# 42.14: running experiment #466: sieve_of_sundaram (182929, 183029)
# 42.21: running experiment #467: sieve_of_sundaram (196598, 196698)
# 42.28: running experiment #468: sieve_of_eratosthenes (75045, 85045)
# 42.29: running experiment #469: sieve_of_sundaram (207509, 207519)
# 42.37: running experiment #470: sieve_of_sundaram (344903, 345903)
# 42.51: running experiment #471: sieve_of_sundaram (398443, 398453)
# 42.68: running experiment #472: naive_algorithm (373771, 373781)
# 42.68: running experiment #473: sieve_of_eratosthenes (778004, 779004)
# 42.78: running experiment #474: sieve_of_sundaram (300348, 301348)
# 42.9: running experiment #475: naive_algorithm (760310, 760410)
# 42.9: running experiment #476: naive_algorithm (950137, 950237)
# 42.9: running experiment #477: sieve_of_sundaram (432690, 433690)
# 43.09: running experiment #478: naive_algorithm (607272, 608272)
# 43.09: running experiment #479: sieve_of_eratosthenes (11029, 21029)
# 43.09: running experiment #480: naive_algorithm (360196, 370196)
# 43.13: running experiment #481: naive_algorithm (228886, 228986)
# 43.13: running experiment #482: sieve_of_sundaram (638257, 638357)
# 43.41: running experiment #483: sieve_of_sundaram (212805, 212905)
# 43.49: running experiment #484: sieve_of_sundaram (64239, 65239)
# 43.51: running experiment #485: sieve_of_eratosthenes (56041, 56141)
# 43.52: running experiment #486: sieve_of_sundaram (917432, 918432)
# 43.93: running experiment #487: sieve_of_eratosthenes (760043, 760053)
# 44.02: running experiment #488: sieve_of_sundaram (103474, 113474)
# 44.06: running experiment #489: sieve_of_sundaram (245104, 245204)
# 44.16: running experiment #490: sieve_of_sundaram (794469, 804469)
# 44.51: running experiment #491: naive_algorithm (632552, 633552)
# 44.51: running experiment #492: sieve_of_sundaram (912145, 922145)
# 44.94: running experiment #493: sieve_of_eratosthenes (807544, 807644)
# 45.04: running experiment #494: sieve_of_eratosthenes (183503, 193503)
# 45.06: running experiment #495: sieve_of_sundaram (610591, 611591)
# 45.32: running experiment #496: sieve_of_sundaram (675452, 676452)
# 45.62: running experiment #497: sieve_of_sundaram (70231, 70331)
# 45.65: running experiment #498: sieve_of_eratosthenes (50322, 50422)
# 45.65: running experiment #499: sieve_of_sundaram (567073, 568073)
# 45.89: running experiment #500: naive_algorithm (635513, 635523)
# 45.89: running experiment #501: sieve_of_eratosthenes (219854, 219954)
# 45.92: running experiment #502: sieve_of_sundaram (695079, 695179)
# 46.23: running experiment #503: sieve_of_eratosthenes (876502, 877502)
# 46.34: running experiment #504: sieve_of_sundaram (978380, 979380)
# 46.79: running experiment #505: naive_algorithm (569369, 569469)
# 46.79: running experiment #506: naive_algorithm (29195, 39195)
# 46.81: running experiment #507: sieve_of_eratosthenes (731821, 731831)
# 46.9: running experiment #508: naive_algorithm (513892, 514892)
# 46.9: running experiment #509: sieve_of_eratosthenes (468830, 469830)
# 46.96: running experiment #510: sieve_of_sundaram (812818, 822818)
# 47.33: running experiment #511: sieve_of_eratosthenes (905792, 905802)
# 47.45: running experiment #512: naive_algorithm (480854, 480954)
# 47.45: running experiment #513: sieve_of_sundaram (426957, 427057)
# 47.63: running experiment #514: naive_algorithm (727736, 727836)
# 47.63: running experiment #515: sieve_of_sundaram (472379, 472479)
# 47.83: running experiment #516: sieve_of_sundaram (183381, 183481)
# 47.9: running experiment #517: sieve_of_sundaram (439741, 439751)
# 48.09: running experiment #518: naive_algorithm (781356, 781456)
# 48.09: running experiment #519: sieve_of_sundaram (439335, 439345)
# 48.29: running experiment #520: naive_algorithm (115091, 116091)
# 48.29: running experiment #521: sieve_of_eratosthenes (886763, 886773)
# 48.41: running experiment #522: sieve_of_eratosthenes (191799, 191899)
# 48.43: running experiment #523: sieve_of_eratosthenes (869577, 870577)
# 48.54: running experiment #524: sieve_of_sundaram (494009, 494019)
# 48.76: running experiment #525: sieve_of_eratosthenes (629672, 629772)
# 48.84: running experiment #526: sieve_of_eratosthenes (162208, 162308)
# 48.86: running experiment #527: naive_algorithm (296647, 297647)
# 48.86: running experiment #528: sieve_of_sundaram (467930, 468930)
# 49.06: running experiment #529: naive_algorithm (653681, 653691)
# 49.06: running experiment #530: sieve_of_eratosthenes (335751, 345751)
# 49.1: running experiment #531: sieve_of_sundaram (512081, 512181)
# 49.32: running experiment #532: sieve_of_eratosthenes (783690, 783790)
# 49.43: running experiment #533: sieve_of_sundaram (848362, 849362)
# 49.8: running experiment #534: sieve_of_eratosthenes (293810, 294810)
# 49.84: running experiment #535: sieve_of_eratosthenes (608727, 618727)
# 49.92: running experiment #536: naive_algorithm (895764, 905764)
# 49.97: running experiment #537: sieve_of_sundaram (818507, 828507)
# 50.35: running experiment #538: naive_algorithm (878417, 879417)
# 50.35: running experiment #539: sieve_of_eratosthenes (39089, 39189)
# 50.36: running experiment #540: sieve_of_sundaram (551793, 551893)
# 50.59: running experiment #541: naive_algorithm (439411, 439421)
# 50.59: running experiment #542: sieve_of_eratosthenes (918606, 919606)
# 50.72: running experiment #543: sieve_of_sundaram (132449, 132459)
# 50.77: running experiment #544: sieve_of_sundaram (451423, 452423)
# 50.96: running experiment #545: naive_algorithm (663062, 673062)
# 51.01: running experiment #546: sieve_of_eratosthenes (225196, 225206)
# 51.04: running experiment #547: naive_algorithm (481523, 482523)
# 51.04: running experiment #548: sieve_of_sundaram (986782, 987782)
# 51.5: running experiment #549: sieve_of_sundaram (257274, 267274)
# 51.61: running experiment #550: sieve_of_eratosthenes (24156, 24166)
# 51.61: running experiment #551: naive_algorithm (111513, 111523)
# 51.61: running experiment #552: sieve_of_eratosthenes (926621, 926721)
# 51.73: running experiment #553: naive_algorithm (145950, 145960)
# 51.73: running experiment #554: sieve_of_sundaram (465754, 465764)
# 51.94: running experiment #555: sieve_of_sundaram (86569, 87569)
# 51.97: running experiment #556: naive_algorithm (230441, 240441)
# 52.0: running experiment #557: sieve_of_eratosthenes (885816, 885916)
# 52.12: running experiment #558: sieve_of_eratosthenes (7682, 7782)
# 52.12: running experiment #559: sieve_of_eratosthenes (504434, 504534)
# 52.18: running experiment #560: sieve_of_eratosthenes (143561, 143661)
# 52.2: running experiment #561: sieve_of_eratosthenes (659135, 659235)
# 52.28: running experiment #562: sieve_of_eratosthenes (429753, 429763)
# 52.34: running experiment #563: naive_algorithm (520202, 521202)
# 52.34: running experiment #564: sieve_of_eratosthenes (500745, 501745)
# 52.41: running experiment #565: naive_algorithm (967624, 967634)
# 52.41: running experiment #566: naive_algorithm (956100, 956200)
# 52.41: running experiment #567: sieve_of_sundaram (610443, 610543)
# 52.68: running experiment #568: sieve_of_sundaram (411763, 421763)
# 52.86: running experiment #569: sieve_of_eratosthenes (516995, 517005)
# 52.92: running experiment #570: sieve_of_eratosthenes (559715, 559815)
# 52.99: running experiment #571: sieve_of_sundaram (346074, 346084)
# 53.13: running experiment #572: naive_algorithm (164913, 164923)
# 53.13: running experiment #573: naive_algorithm (663391, 664391)
# 53.14: running experiment #574: sieve_of_sundaram (716914, 717914)
# 53.45: running experiment #575: sieve_of_eratosthenes (926465, 926475)
# 53.57: running experiment #576: sieve_of_sundaram (844675, 844775)
# 53.95: running experiment #577: naive_algorithm (727810, 728810)
# 53.96: running experiment #578: sieve_of_sundaram (42003, 43003)
# 53.97: running experiment #579: sieve_of_sundaram (803599, 803609)
# 54.32: running experiment #580: sieve_of_sundaram (175479, 176479)
# 54.38: running experiment #581: sieve_of_sundaram (118606, 128606)
# 54.43: running experiment #582: sieve_of_eratosthenes (33399, 34399)
# 54.44: running experiment #583: sieve_of_sundaram (685957, 695957)
# 54.75: running experiment #584: naive_algorithm (517610, 518610)
# 54.76: running experiment #585: sieve_of_eratosthenes (271135, 271145)
# 54.79: running experiment #586: sieve_of_sundaram (851284, 861284)
# 55.17: running experiment #587: naive_algorithm (480308, 490308)
# 55.21: running experiment #588: sieve_of_sundaram (764442, 765442)
# 55.55: running experiment #589: sieve_of_eratosthenes (377068, 377168)
# 55.6: running experiment #590: sieve_of_eratosthenes (701948, 701958)
# 55.69: running experiment #591: sieve_of_eratosthenes (528736, 528836)
# 55.75: running experiment #592: sieve_of_sundaram (956631, 956641)
# 56.18: running experiment #593: naive_algorithm (626503, 627503)
# 56.18: running experiment #594: sieve_of_eratosthenes (767983, 777983)
# 56.28: running experiment #595: sieve_of_sundaram (542520, 552520)
# 56.53: running experiment #596: sieve_of_sundaram (286657, 287657)
# 56.64: running experiment #597: naive_algorithm (347021, 348021)
# 56.65: running experiment #598: sieve_of_sundaram (76153, 86153)
# 56.68: running experiment #599: sieve_of_sundaram (794014, 804014)
# 57.04: running experiment #600: sieve_of_sundaram (190945, 191045)
# 57.11: running experiment #601: sieve_of_sundaram (602320, 612320)
# 57.37: running experiment #602: naive_algorithm (144802, 144902)
# 57.37: running experiment #603: naive_algorithm (268465, 268565)
# 57.37: running experiment #604: sieve_of_eratosthenes (857951, 858951)
# 57.49: running experiment #605: sieve_of_eratosthenes (838270, 839270)
# 57.59: running experiment #606: naive_algorithm (499689, 499699)
# 57.59: running experiment #607: sieve_of_sundaram (353599, 354599)
# 57.74: running experiment #608: sieve_of_eratosthenes (487182, 488182)
# 57.8: running experiment #609: sieve_of_eratosthenes (590311, 590411)
# 57.87: running experiment #610: naive_algorithm (417718, 418718)
# 57.88: running experiment #611: naive_algorithm (374893, 374903)
# 57.88: running experiment #612: naive_algorithm (617798, 617808)
# 57.88: running experiment #613: naive_algorithm (772600, 772700)
# 57.88: running experiment #614: naive_algorithm (267774, 267874)
# 57.88: running experiment #615: sieve_of_sundaram (132861, 132871)
# 57.93: running experiment #616: sieve_of_sundaram (753967, 763967)
# 58.26: running experiment #617: sieve_of_eratosthenes (47835, 57835)
# 58.27: running experiment #618: sieve_of_eratosthenes (446357, 446367)
# 58.33: running experiment #619: sieve_of_eratosthenes (418530, 428530)
# 58.38: running experiment #620: naive_algorithm (121588, 131588)
# 58.4: running experiment #621: sieve_of_eratosthenes (986065, 986165)
# 58.53: running experiment #622: sieve_of_eratosthenes (621033, 622033)
# 58.62: running experiment #623: sieve_of_eratosthenes (346067, 346077)
# 58.66: running experiment #624: sieve_of_eratosthenes (817957, 818957)
# 58.77: running experiment #625: sieve_of_sundaram (30654, 30664)
# 58.78: running experiment #626: sieve_of_eratosthenes (481207, 482207)
# 58.84: running experiment #627: sieve_of_sundaram (781112, 781122)
# 59.18: running experiment #628: sieve_of_sundaram (190624, 190634)
# 59.26: running experiment #629: sieve_of_sundaram (268918, 269018)
# 59.37: running experiment #630: sieve_of_sundaram (23631, 33631)
# 59.38: running experiment #631: naive_algorithm (398766, 399766)
# 59.38: running experiment #632: naive_algorithm (818182, 818192)
# 59.38: running experiment #633: sieve_of_eratosthenes (328369, 328469)
# 59.43: running experiment #634: naive_algorithm (12950, 22950)
# 59.44: running experiment #635: naive_algorithm (167881, 167981)
# 59.44: running experiment #636: sieve_of_sundaram (284210, 284220)
# 59.56: running experiment #637: sieve_of_eratosthenes (101274, 101284)
# 59.57: running experiment #638: sieve_of_sundaram (803729, 803829)
# 59.93: running experiment #639: naive_algorithm (109240, 119240)
# 59.95: running experiment #640: naive_algorithm (594492, 594592)
# 59.95: running experiment #641: naive_algorithm (456744, 456844)
# 59.95: running experiment #642: naive_algorithm (535905, 545905)
# 60.0: running experiment #643: sieve_of_eratosthenes (316928, 316938)
# 60.04: running experiment #644: sieve_of_sundaram (438536, 439536)
# 60.22: running experiment #645: naive_algorithm (134637, 144637)
# 60.25: running experiment #646: sieve_of_sundaram (834903, 835903)
# 60.61: running experiment #647: sieve_of_sundaram (869765, 879765)
# 61.01: running experiment #648: sieve_of_eratosthenes (261347, 271347)
# 61.04: running experiment #649: naive_algorithm (224117, 225117)
# 61.04: running experiment #650: naive_algorithm (98696, 108696)
# 61.07: running experiment #651: sieve_of_eratosthenes (190694, 200694)
# 61.09: running experiment #652: sieve_of_eratosthenes (397373, 397383)
# 61.14: running experiment #653: sieve_of_eratosthenes (908579, 908589)
# 61.25: running experiment #654: sieve_of_sundaram (430979, 430989)
# 61.43: running experiment #655: naive_algorithm (217138, 217148)
# 61.44: running experiment #656: sieve_of_eratosthenes (578927, 579027)
# 61.51: running experiment #657: sieve_of_eratosthenes (722783, 732783)
# 61.61: running experiment #658: naive_algorithm (510437, 510447)
# 61.61: running experiment #659: sieve_of_eratosthenes (782715, 792715)
# 61.71: running experiment #660: sieve_of_eratosthenes (283664, 283674)
# 61.74: running experiment #661: naive_algorithm (791028, 791128)
# 61.74: running experiment #662: sieve_of_sundaram (59466, 69466)
# 61.77: running experiment #663: naive_algorithm (150772, 160772)
# 61.8: running experiment #664: naive_algorithm (547812, 547912)
# 61.8: running experiment #665: sieve_of_sundaram (802913, 803013)
# 62.16: running experiment #666: sieve_of_eratosthenes (667204, 667214)
# 62.25: running experiment #667: sieve_of_sundaram (909121, 909131)
# 62.65: running experiment #668: sieve_of_eratosthenes (649271, 659271)
# 62.73: running experiment #669: naive_algorithm (566104, 566204)
# 62.73: running experiment #670: sieve_of_eratosthenes (915280, 916280)
# 62.85: running experiment #671: sieve_of_eratosthenes (80410, 90410)
# 62.86: running experiment #672: naive_algorithm (295128, 295228)
# 62.86: running experiment #673: sieve_of_sundaram (546082, 556082)
# 63.1: running experiment #674: naive_algorithm (913091, 914091)
# 63.1: running experiment #675: naive_algorithm (606144, 607144)
# 63.11: running experiment #676: sieve_of_eratosthenes (291975, 301975)
# 63.15: running experiment #677: sieve_of_sundaram (196805, 197805)
# 63.22: running experiment #678: sieve_of_eratosthenes (672863, 672963)
# 63.31: running experiment #679: sieve_of_eratosthenes (206775, 206875)
# 63.33: running experiment #680: naive_algorithm (396532, 396632)
# 63.34: running experiment #681: naive_algorithm (540830, 540840)
# 63.34: running experiment #682: sieve_of_eratosthenes (779057, 779067)
# 63.44: running experiment #683: sieve_of_sundaram (153626, 163626)
# 63.51: running experiment #684: sieve_of_eratosthenes (959499, 959599)
# 63.63: running experiment #685: sieve_of_sundaram (290332, 291332)
# 63.75: running experiment #686: sieve_of_sundaram (554458, 554468)
# 64.0: running experiment #687: sieve_of_eratosthenes (75243, 76243)
# 64.01: running experiment #688: sieve_of_eratosthenes (173146, 174146)
# 64.03: running experiment #689: naive_algorithm (741656, 751656)
# 64.08: running experiment #690: naive_algorithm (180443, 180453)
# 64.08: running experiment #691: sieve_of_eratosthenes (13533, 13633)
# 64.08: running experiment #692: sieve_of_sundaram (6826, 16826)
# 64.09: running experiment #693: sieve_of_eratosthenes (954886, 954896)
# 64.21: running experiment #694: naive_algorithm (120916, 130916)
# 64.23: running experiment #695: sieve_of_eratosthenes (290055, 290155)
# 64.27: running experiment #696: naive_algorithm (927589, 928589)
# 64.27: running experiment #697: sieve_of_sundaram (640440, 641440)
# 64.55: running experiment #698: naive_algorithm (462672, 472672)
# 64.59: running experiment #699: sieve_of_eratosthenes (824791, 834791)
# 64.7: running experiment #700: sieve_of_eratosthenes (163956, 163966)
# 64.72: running experiment #701: sieve_of_eratosthenes (463785, 473785)
# 64.78: running experiment #702: naive_algorithm (703487, 703497)
# 64.78: running experiment #703: naive_algorithm (324992, 325002)
# 64.78: running experiment #704: sieve_of_sundaram (92025, 93025)
# 64.81: running experiment #705: naive_algorithm (46445, 56445)
# 64.83: running experiment #706: sieve_of_eratosthenes (385266, 395266)
# 64.89: running experiment #707: sieve_of_sundaram (738050, 738060)
# 65.21: running experiment #708: sieve_of_eratosthenes (870377, 870387)
# 65.32: running experiment #709: sieve_of_sundaram (551721, 551731)
# 65.56: running experiment #710: sieve_of_eratosthenes (489648, 499648)
# 65.63: running experiment #711: sieve_of_sundaram (871570, 872570)
# 66.02: running experiment #712: sieve_of_eratosthenes (972637, 973637)
# 66.15: running experiment #713: sieve_of_sundaram (424859, 424869)
# 66.32: running experiment #714: sieve_of_eratosthenes (40913, 41013)
# ...
# 89.62: running experiment #968: sieve_of_sundaram (169756, 179756)
# 89.69: running experiment #969: sieve_of_sundaram (688435, 698435)
# 90.0: running experiment #970: sieve_of_sundaram (511278, 512278)
# 90.23: running experiment #971: sieve_of_sundaram (476219, 486219)
# 90.43: running experiment #972: sieve_of_eratosthenes (28559, 28569)
# 90.43: running experiment #973: naive_algorithm (270864, 271864)
# 90.44: running experiment #974: naive_algorithm (230928, 240928)
# 90.47: running experiment #975: sieve_of_sundaram (222370, 232370)
# 90.56: running experiment #976: naive_algorithm (379604, 380604)
# 90.56: running experiment #977: sieve_of_eratosthenes (147335, 147345)
# 90.58: running experiment #978: sieve_of_sundaram (873547, 873647)
# 90.97: running experiment #979: sieve_of_sundaram (658146, 658156)
# 91.25: running experiment #980: naive_algorithm (7184, 8184)
# 91.25: running experiment #981: sieve_of_sundaram (652113, 652213)
# 91.54: running experiment #982: sieve_of_eratosthenes (670174, 680174)
# 91.63: running experiment #983: naive_algorithm (587121, 597121)
# 91.68: running experiment #984: sieve_of_sundaram (155953, 156053)
# 91.74: running experiment #985: naive_algorithm (183175, 193175)
# 91.77: running experiment #986: sieve_of_sundaram (923212, 924212)
# 92.19: running experiment #987: sieve_of_sundaram (354194, 354294)
# 92.34: running experiment #988: naive_algorithm (980099, 980109)
# 92.34: running experiment #989: sieve_of_sundaram (534502, 534602)
# 92.58: running experiment #990: sieve_of_eratosthenes (534436, 535436)
# 92.64: running experiment #991: sieve_of_sundaram (922671, 922681)
# 93.07: running experiment #992: sieve_of_eratosthenes (969414, 969514)
# 93.19: running experiment #993: sieve_of_eratosthenes (996255, 996265)
# 93.34: running experiment #994: naive_algorithm (489009, 499009)
# 93.38: running experiment #995: naive_algorithm (898412, 898422)
# 93.38: running experiment #996: naive_algorithm (295619, 295629)
# 93.38: running experiment #997: sieve_of_eratosthenes (638307, 648307)
# 93.46: running experiment #998: sieve_of_sundaram (526029, 526039)
# 93.68: running experiment #999: sieve_of_sundaram (843902, 844902)
# 94.06: running experiment #1000: naive_algorithm (65168, 66168)
# 94.06: running experiment #1001: sieve_of_sundaram (52624, 52634)
# 94.08: running experiment #1002: naive_algorithm (257783, 258783)
# 94.08: running experiment #1003: sieve_of_eratosthenes (913454, 914454)
# 94.2: running experiment #1004: sieve_of_sundaram (908901, 909901)
# 94.6: running experiment #1005: sieve_of_eratosthenes (364299, 374299)
# 94.65: running experiment #1006: sieve_of_eratosthenes (152851, 153851)
# 94.67: running experiment #1007: sieve_of_eratosthenes (719418, 719428)
# 94.76: running experiment #1008: sieve_of_sundaram (579549, 580549)
# 95.0: running experiment #1009: naive_algorithm (724565, 724665)
# 95.0: running experiment #1010: sieve_of_sundaram (595889, 605889)
# 95.26: running experiment #1011: naive_algorithm (297868, 298868)
# 95.27: running experiment #1012: sieve_of_eratosthenes (313851, 313861)
# 95.31: running experiment #1013: sieve_of_sundaram (486829, 486929)
# 95.52: running experiment #1014: sieve_of_eratosthenes (661003, 661013)
# 95.61: running experiment #1015: naive_algorithm (135948, 136048)
# 95.61: running experiment #1016: naive_algorithm (217712, 227712)
# 95.64: running experiment #1017: naive_algorithm (49855, 49865)
# 95.64: running experiment #1018: sieve_of_eratosthenes (856624, 866624)
# 95.75: running experiment #1019: sieve_of_sundaram (676269, 686269)
# 96.06: running experiment #1020: sieve_of_sundaram (610881, 610981)
# 96.33: running experiment #1021: sieve_of_sundaram (379027, 389027)
# 96.49: running experiment #1022: sieve_of_sundaram (731082, 731182)
# 96.81: running experiment #1023: sieve_of_eratosthenes (762509, 763509)
# 96.91: running experiment #1024: naive_algorithm (7631, 7731)
# 96.91: running experiment #1025: naive_algorithm (181051, 191051)
# 96.94: running experiment #1026: sieve_of_sundaram (938631, 938731)
# 97.37: running experiment #1027: sieve_of_sundaram (838174, 838184)
# 97.74: running experiment #1028: sieve_of_eratosthenes (604447, 604547)
# 97.82: running experiment #1029: sieve_of_sundaram (867399, 867409)
# 98.2: running experiment #1030: sieve_of_sundaram (509513, 519513)
# 98.42: running experiment #1031: sieve_of_sundaram (60845, 60855)
# 98.45: running experiment #1032: sieve_of_sundaram (504042, 505042)
# 98.66: running experiment #1033: sieve_of_sundaram (731404, 741404)
# 99.0: running experiment #1034: sieve_of_sundaram (870436, 871436)
# 99.39: running experiment #1035: naive_algorithm (554103, 564103)
# 99.44: running experiment #1036: sieve_of_eratosthenes (105319, 105329)
# 99.45: running experiment #1037: naive_algorithm (475506, 475516)
# 99.45: running experiment #1038: sieve_of_sundaram (78819, 78829)
# 99.48: running experiment #1039: naive_algorithm (666003, 676003)
# 99.53: running experiment #1040: sieve_of_eratosthenes (2289, 3289)
# 99.53: running experiment #1041: naive_algorithm (483190, 483290)
# 99.53: running experiment #1042: sieve_of_sundaram (316835, 317835)
# 99.66: running experiment #1043: naive_algorithm (340751, 340761)
# 99.66: running experiment #1044: naive_algorithm (782321, 782331)
# 99.66: running experiment #1045: sieve_of_eratosthenes (272499, 272599)
# 99.7: running experiment #1046: sieve_of_eratosthenes (160565, 170565)
# 99.72: running experiment #1047: naive_algorithm (539625, 549625)
# 99.77: running experiment #1048: sieve_of_sundaram (431842, 431942)
# 99.95: running experiment #1049: naive_algorithm (581583, 581593)
# 99.95: running experiment #1050: sieve_of_eratosthenes (445013, 445113)
# 100.0: running experiment #1051: sieve_of_eratosthenes (589946, 590046)
# 100.08: running experiment #1052: naive_algorithm (163529, 164529)
# 100.08: running experiment #1053: naive_algorithm (363655, 364655)
# 100.08: running experiment #1054: sieve_of_eratosthenes (936260, 946260)
# 100.21: running experiment #1055: sieve_of_sundaram (86135, 86235)
# 100.24: running experiment #1056: naive_algorithm (227733, 228733)
# 100.25: running experiment #1057: sieve_of_sundaram (976057, 976067)
# 100.69: running experiment #1058: sieve_of_eratosthenes (936486, 936586)
# 100.82: running experiment #1059: sieve_of_sundaram (292696, 302696)
# 100.95: running experiment #1060: sieve_of_sundaram (471738, 471838)
# 101.14: running experiment #1061: naive_algorithm (537749, 537849)
# 101.15: running experiment #1062: sieve_of_eratosthenes (730494, 730504)
# 101.24: running experiment #1063: naive_algorithm (503686, 503696)
# 101.24: running experiment #1064: sieve_of_eratosthenes (846524, 847524)
# 101.34: running experiment #1065: sieve_of_eratosthenes (388203, 398203)
# 101.39: running experiment #1066: sieve_of_eratosthenes (349278, 349378)
# 101.43: running experiment #1067: sieve_of_eratosthenes (503073, 503083)
# 101.5: running experiment #1068: sieve_of_sundaram (489253, 489263)
# 101.71: running experiment #1069: sieve_of_sundaram (181110, 182110)
# 101.78: running experiment #1070: sieve_of_sundaram (701619, 701629)
# 102.09: running experiment #1071: sieve_of_eratosthenes (182333, 182343)
# 102.11: running experiment #1072: sieve_of_eratosthenes (907463, 908463)
# 102.23: running experiment #1073: sieve_of_sundaram (431260, 441260)
# 102.42: running experiment #1074: sieve_of_sundaram (692627, 692727)
# 102.72: running experiment #1075: sieve_of_sundaram (838484, 838494)
# 103.09: running experiment #1076: sieve_of_sundaram (426451, 436451)
# 103.27: running experiment #1077: sieve_of_eratosthenes (450462, 450562)
# 103.32: running experiment #1078: naive_algorithm (444306, 454306)
# 103.37: running experiment #1079: naive_algorithm (267811, 267911)
# 103.37: running experiment #1080: naive_algorithm (336020, 336120)
# 103.37: running experiment #1081: naive_algorithm (622091, 622191)
# 103.37: running experiment #1082: sieve_of_sundaram (458950, 468950)
# 103.56: running experiment #1083: sieve_of_sundaram (989501, 989601)
# 104.01: running experiment #1084: sieve_of_eratosthenes (813364, 823364)
# 104.11: running experiment #1085: sieve_of_sundaram (448856, 448956)
# 104.3: running experiment #1086: sieve_of_eratosthenes (670347, 671347)
# 104.38: running experiment #1087: sieve_of_eratosthenes (855846, 855856)
# 104.5: running experiment #1088: sieve_of_eratosthenes (466457, 476457)
# 104.56: running experiment #1089: sieve_of_eratosthenes (532420, 532430)
# 104.63: running experiment #1090: sieve_of_sundaram (244392, 254392)
# 104.73: running experiment #1091: sieve_of_sundaram (519544, 529544)
# 104.95: running experiment #1092: sieve_of_sundaram (379000, 380000)
# 105.11: running experiment #1093: naive_algorithm (816644, 817644)
# 105.12: running experiment #1094: naive_algorithm (959470, 959480)
# 105.12: running experiment #1095: sieve_of_sundaram (347691, 347701)
# 105.26: running experiment #1096: naive_algorithm (597494, 607494)
# 105.3: running experiment #1097: naive_algorithm (62935, 72935)
# 105.33: running experiment #1098: sieve_of_eratosthenes (810403, 811403)
# 105.43: running experiment #1099: sieve_of_sundaram (894132, 904132)
# 105.84: running experiment #1100: naive_algorithm (799754, 809754)
# 105.89: running experiment #1101: sieve_of_sundaram (795185, 796185)
# 106.24: running experiment #1102: sieve_of_sundaram (96753, 96763)
# 106.28: running experiment #1103: sieve_of_eratosthenes (867006, 868006)
# 106.39: running experiment #1104: sieve_of_sundaram (542872, 552872)
# 106.63: running experiment #1105: sieve_of_sundaram (53213, 53223)
# 106.65: running experiment #1106: naive_algorithm (442137, 442147)
# 106.65: running experiment #1107: sieve_of_sundaram (335829, 335839)
# 106.78: running experiment #1108: sieve_of_sundaram (578671, 578771)
# 107.03: running experiment #1109: naive_algorithm (209130, 209140)
# 107.04: running experiment #1110: sieve_of_sundaram (751783, 751793)
# 107.36: running experiment #1111: sieve_of_eratosthenes (495408, 496408)
# 107.43: running experiment #1112: naive_algorithm (127583, 127593)
# 107.43: running experiment #1113: sieve_of_eratosthenes (751421, 751521)
# 107.52: running experiment #1114: naive_algorithm (193850, 203850)
# 107.55: running experiment #1115: naive_algorithm (412115, 412215)
# 107.55: running experiment #1116: sieve_of_eratosthenes (15349, 15359)
# 107.55: running experiment #1117: sieve_of_eratosthenes (267719, 267729)
# 107.58: running experiment #1118: sieve_of_eratosthenes (369999, 370009)
# 107.63: running experiment #1119: sieve_of_sundaram (213785, 213795)
# 107.71: running experiment #1120: naive_algorithm (846935, 856935)
# 107.77: running experiment #1121: naive_algorithm (743035, 744035)
# 107.77: running experiment #1122: sieve_of_sundaram (915034, 915044)
# 108.18: running experiment #1123: sieve_of_eratosthenes (706620, 716620)
# 108.27: running experiment #1124: sieve_of_eratosthenes (836618, 837618)
# 108.38: running experiment #1125: sieve_of_sundaram (159690, 159790)
# 108.44: running experiment #1126: sieve_of_sundaram (323865, 323965)
# 108.57: running experiment #1127: sieve_of_sundaram (280749, 280759)
# 108.68: running experiment #1128: naive_algorithm (577125, 578125)
# 108.69: running experiment #1129: naive_algorithm (640028, 640128)
# 108.69: running experiment #1130: naive_algorithm (999145, 1009145)
# 108.75: running experiment #1131: sieve_of_eratosthenes (653529, 653539)
# 108.83: running experiment #1132: naive_algorithm (452, 1452)
# 108.83: running experiment #1133: sieve_of_sundaram (88829, 89829)
# 108.87: running experiment #1134: naive_algorithm (635290, 635300)
# 108.87: running experiment #1135: naive_algorithm (388516, 389516)
# 108.87: running experiment #1136: sieve_of_sundaram (722058, 722158)
# 109.19: running experiment #1137: sieve_of_sundaram (210643, 211643)
# 109.27: running experiment #1138: sieve_of_sundaram (231858, 231958)
# 109.36: running experiment #1139: sieve_of_sundaram (178918, 178928)
# 109.43: running experiment #1140: sieve_of_eratosthenes (511417, 511427)
# 109.5: running experiment #1141: sieve_of_eratosthenes (838270, 839270)
# 109.61: running experiment #1142: sieve_of_eratosthenes (468595, 468695)
# 109.67: running experiment #1143: sieve_of_eratosthenes (843155, 843255)
# 109.78: running experiment #1144: naive_algorithm (500687, 501687)
# 109.78: running experiment #1145: sieve_of_sundaram (463619, 473619)
# 109.99: running experiment #1146: sieve_of_eratosthenes (325545, 325555)
# 110.03: running experiment #1147: sieve_of_sundaram (391934, 401934)
# 110.2: running experiment #1148: naive_algorithm (501529, 501629)
# 110.2: running experiment #1149: sieve_of_sundaram (386126, 386226)
# 110.36: running experiment #1150: naive_algorithm (350084, 351084)
# 110.36: running experiment #1151: sieve_of_sundaram (446557, 447557)
# 110.55: running experiment #1152: sieve_of_sundaram (671154, 681154)
# 110.85: running experiment #1153: sieve_of_sundaram (743163, 753163)
# 111.19: running experiment #1154: naive_algorithm (422084, 423084)
# 111.19: running experiment #1155: sieve_of_eratosthenes (483005, 483015)
# 111.25: running experiment #1156: naive_algorithm (183672, 184672)
# 111.25: running experiment #1157: sieve_of_sundaram (3806, 3906)
# 111.25: running experiment #1158: naive_algorithm (387154, 387254)
# 111.25: running experiment #1159: sieve_of_sundaram (488239, 488339)
# 111.46: running experiment #1160: sieve_of_eratosthenes (566428, 566528)
# 111.53: running experiment #1161: naive_algorithm (529106, 529206)
# 111.53: running experiment #1162: sieve_of_eratosthenes (575639, 575649)
# 111.6: running experiment #1163: sieve_of_sundaram (389341, 390341)
# 111.76: running experiment #1164: sieve_of_eratosthenes (981162, 981262)
# 111.89: running experiment #1165: sieve_of_eratosthenes (426300, 426310)
# 111.94: running experiment #1166: sieve_of_eratosthenes (951889, 952889)
# 112.06: running experiment #1167: naive_algorithm (239996, 240006)
# 112.06: running experiment #1168: sieve_of_eratosthenes (627295, 628295)
# 112.15: running experiment #1169: sieve_of_eratosthenes (407845, 417845)
# 112.2: running experiment #1170: sieve_of_eratosthenes (466982, 476982)
# 112.25: running experiment #1171: naive_algorithm (618916, 618926)
# 112.25: running experiment #1172: sieve_of_eratosthenes (898059, 908059)
# 112.37: running experiment #1173: naive_algorithm (939797, 940797)
# 112.38: running experiment #1174: sieve_of_eratosthenes (326284, 326294)
# 112.42: running experiment #1175: sieve_of_sundaram (814008, 814108)
# 112.78: running experiment #1176: naive_algorithm (963675, 973675)
# 112.84: running experiment #1177: naive_algorithm (324444, 324544)
# 112.84: running experiment #1178: naive_algorithm (770053, 770153)
# 112.84: running experiment #1179: naive_algorithm (334761, 335761)
# 112.85: running experiment #1180: sieve_of_eratosthenes (118052, 128052)
# 112.86: running experiment #1181: sieve_of_sundaram (373079, 373089)
# 113.02: running experiment #1182: naive_algorithm (76762, 76862)
# 113.02: running experiment #1183: sieve_of_sundaram (479565, 479665)
# 113.22: running experiment #1184: sieve_of_sundaram (584024, 594024)
# 113.47: running experiment #1185: sieve_of_eratosthenes (550089, 550099)
# 113.54: running experiment #1186: naive_algorithm (439654, 439664)
# 113.54: running experiment #1187: sieve_of_sundaram (393341, 393351)
# 113.71: running experiment #1188: naive_algorithm (171823, 172823)
# 113.71: running experiment #1189: sieve_of_sundaram (579762, 580762)
# 113.97: running experiment #1190: naive_algorithm (508888, 508898)
# 113.97: running experiment #1191: sieve_of_eratosthenes (290776, 291776)
# 114.01: running experiment #1192: naive_algorithm (281758, 281858)
# 114.01: running experiment #1193: naive_algorithm (438847, 448847)
# 114.05: running experiment #1194: sieve_of_eratosthenes (610182, 620182)
# 114.13: running experiment #1195: sieve_of_eratosthenes (128122, 129122)
# 114.15: running experiment #1196: sieve_of_eratosthenes (347046, 348046)
# 114.19: running experiment #1197: sieve_of_eratosthenes (163848, 163948)
# 114.21: running experiment #1198: sieve_of_sundaram (868989, 868999)
# 114.6: running experiment #1199: sieve_of_eratosthenes (139026, 139036)
# done

# %%
start = time.time() # Gets the current system time
sieve_of_sundaram(12345, 12345+10000)
end = time.time()
computation_time = end - start # Time in seconds
